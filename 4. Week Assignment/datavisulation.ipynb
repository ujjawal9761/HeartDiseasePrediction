# %% [markdown]
# # 1.a Importing needed packages

# %%
# importing the required library with alias names
import numpy as np
# importing pandas with alias as pd
import pandas as pd
# importing seaborn with alias name as sns
import seaborn as sns
# importing the pyplot module of matplotlib package having a
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #  1.b Loading the datset

# %%
# loading the dataset and assigning it to a variable
heartdisease=pd.read_csv('Predictingheartdisease.csv')
# displaying some head or initiall data
heartdisease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# # 1.c Handling categorical variables in the given dataset

# %%
# evaluating the datatypes of each attribute value using the dtypes attribute of dataframa

heartdisease.dtypes

# as we can see that our dataset doesnot have any cateogoricial data so no need to handle it
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# ## Since our dataset has only int and float value also it does not have any categoricial data  so no need to handle or convert them

# %% [markdown]
# #  2.a Taking each attribute for bivariate analysis

# %%
# seperating each attribute along with the target value
predictingValue = heartdisease.target
# having all the attributes in seperate variables that can be used for bi as well as univariate analysis
y = heartdisease.age
y1 = heartdisease.sex
y2 = heartdisease.cp
y3 = heartdisease.trestbps
y4 = heartdisease.chol
y5 = heartdisease.fbs
y6 = heartdisease.restecg
y7 = heartdisease.thalach
y8 = heartdisease.exang
y9 = heartdisease.oldpeak
y10 = heartdisease.slope
y11 = heartdisease.ca
y12 = heartdisease.thal

# %% [markdown]
# # 2.b Plotting target value with the attributes of the dataset

# %%
# ploting a barplot between the target and first attribute
sns.barplot(predictingValue,y,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.show()

# %%
# plotting a bar plot between the target and the second attribute
sns.barplot(predictingValue,y1,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.show()

# %%
# plotting a bar plot between the target and the third attribute
sns.barplot(predictingValue,y2,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.show()

# %%
# plotting a bar plot between the target and the fourth attribute
sns.barplot(predictingValue,y3,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.show()

# %%
# plotting a bar plot between the target and the fifth attribute
sns.barplot(predictingValue,y4,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.show()

# %%
# plotting a bar plot between the target and the sixth attribute
sns.barplot(predictingValue,y5,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.show()

# %%
# plotting a bar plot between the target and the seventh attribute
sns.barplot(predictingValue,y6,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.show()

# %%
# plotting a bar plot between the target and the eight attribute
sns.barplot(predictingValue,y7,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.show()

# %% [markdown]
# # 2.c Analysing each attribute seperately

# %%
sns.distplot(y)
plt.show()

# %%
sns.distplot(y1)
plt.show()

# %%
sns.distplot(y2)
plt.show()

# %%
sns.distplot(y3)
plt.show()

# %%
sns.distplot(y4)
plt.show()

# %%
sns.distplot(y5)
plt.show()

# %%
sns.distplot(y6)
plt.show()

# %%
sns.distplot(y7)
plt.show()

# %% [markdown]
# # 2.d displaying histogram

# %%
heartdisease.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f36b46cb4e0>,
# ...
#       dtype=object)

# %% [markdown]
# # 3.a Handling and analysing outliers

# %%
sns.boxplot(predictingValue,y,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %% [markdown]
# ### Attribute : Age
# ### For 0 : 1 outlier
# ### For 1 : 0 outlier

# %%
sns.boxplot(predictingValue,y1,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %% [markdown]
# ### Attribute : Sex
# ### For 0 : 3 outlier
# ### For 1 : 0 outlier

# %%
sns.boxplot(predictingValue,y2,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %% [markdown]
# ### Attribute : cp
# ### For 0 : 2 outlier
# ### For 1 : 2 outlier

# %%
sns.boxplot(predictingValue,y3,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %% [markdown]
# ### Attribute : trestbps
# ### For 0 : 2 outlier
# ### For 1 : 2 outlier

# %%
sns.boxplot(predictingValue,y4,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %% [markdown]
# ### Attribute : chol
# ### For 0 : 1 outlier
# ### For 1 : 3 outlier

# %%
sns.boxplot(predictingValue,y5,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %% [markdown]
# ### Attribute : fbs
# ### For 0 : 1 outlier
# ### For 1 : 1 outlier

# %%
sns.boxplot(predictingValue,y6,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %% [markdown]
# ### Attribute : restecg
# ### For 0 : 0 outlier
# ### For 1 : 0 outlier

# %%
sns.boxplot(predictingValue,y7,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %% [markdown]
# ### Attribute : thalach
# ### For 0 : 1 outlier
# ### For 1 : 4 outlier

# %%
sns.boxplot(predictingValue,y8,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %% [markdown]
# ### Attribute : exang
# ### For 0 : 0 outlier
# ### For 1 : 0 outlier

# %%
sns.boxplot(predictingValue,y9,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %% [markdown]
# ### Attribute : oldpeak
# ### For 0 : 2 outlier
# ### For 1 : 4 outlier

# %%
sns.boxplot(predictingValue,y10,hue=predictingValue,palette='winter')
plt.legend(title='Target')
plt.grid()
plt.show()

# %% [markdown]
# ### Attribute : slope
# ### For 0 : 0 outlier
# ### For 1 : 0 outlier

# %% [markdown]
# # 3.b checking for Null values or Missing values for each column

# %%
# here we can see that of all the values that are true are Null and those are false are Not Null

heartdisease.isnull()

# Here we see that in our dataset there in no such null value
# Out:
#        age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0    False  False  False     False  False  False    False    False  False
# 1    False  False  False     False  False  False    False    False  False
# 2    False  False  False     False  False  False    False    False  False
# 3    False  False  False     False  False  False    False    False  False
# 4    False  False  False     False  False  False    False    False  False
# ..     ...    ...    ...       ...    ...    ...      ...      ...    ...
# 298  False  False  False     False  False  False    False    False  False
# 299  False  False  False     False  False  False    False    False  False
# 300  False  False  False     False  False  False    False    False  False
# 301  False  False  False     False  False  False    False    False  False
# 302  False  False  False     False  False  False    False    False  False
#
#      oldpeak  slope     ca   thal  target
# ...

# %%
# here it return total null values of a datset

heartdisease.isnull().sum()

# as we can see there is no null value in our dataser as all values are zero
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ###  Our dataset has no missing value so there is no need of removing or droping any row and such

# %% [markdown]
# # 4.a Displaying pairplot

# %%
sns.pairplot(heartdisease)

# %% [markdown]
# # 4.b Making a correlation matrix

# %%
# corr function is used to draw correlation matrix
corr_matrix = heartdisease.corr()
corr_matrix
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...
